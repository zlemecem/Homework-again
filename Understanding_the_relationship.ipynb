# %% [markdown]
# # <font color=blue>Assignments for "Understanding The Relationship"</font>

# %% [markdown]
# To close out this lesson, you're going to do three assignments. For the first assignment, you'll write up a short answer to a question in a Gist file.  For the second two assignments, you'll do your work in Jupyter notebooks, and you should link to those notebooks in the same Gist file.
#
# Please submit a single Gist file containing the answer to first assignment, plus links for second two.

# %% [markdown]
# ## 1. Interpretion and signficance
#
# Suppose that we would like to know how much families in the US are spending on recreation annually. We estimated the following model:
#
# $$ expenditure = 873 + 0.0012annual\_income + 0.00002annual\_income^2 - 223.57have\_kids $$
#
# *expenditure* is the annual spending on recreation in US dollars, *annual_income* is the annual income in US dollars and *have_kids* is a dummy variable indicating the families with children. Interpret the estimated coefficients. What additional statistics should be given in order to make sure that your interpretations make sense statistically. Write up your answer and save in a Gist.

# %% [markdown]
# R-squared, F-statistic, AIC and BIC values, t-test are needed for good estimation.

# %% [markdown]
# ## 2. Weather model
#
# In this exercise, you'll work with the historical temperature data from the previous lesson. To complete this assignment, submit a link in the gist file to the Jupyter notebook containing your solutions to the following tasks:

# %%
import pandas as pd
weather_df = pd.read_csv("https://djl-lms-assets.s3.eu-central-1.amazonaws.com/datasets/weatherHistory.csv")
weather_df.head()
# Out:
#                   Formatted Date  ...                      Daily Summary
# 0  2006-04-01 00:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 1  2006-04-01 01:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 2  2006-04-01 02:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 3  2006-04-01 03:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 4  2006-04-01 04:00:00.000 +0200  ...  Partly cloudy throughout the day.
#
# [5 rows x 12 columns]

# %% [markdown]
# - Build a linear regression model where your target variable is the difference between the *apparenttemperature* and the *temperature*. As explanatory variables, use *humidity* and *windspeed*. Now, estimate your model using OLS. Are the estimated coefficients statistically significant? Are the signs of the estimated coefficients in line with your previous expectations? Interpret the estimated coefficients. What are the relations between the target and the explanatory variables?

# %%
from sklearn import linear_model
Y = weather_df['Apparent Temperature (C)']-weather_df['Temperature (C)']
X = weather_df[['Humidity','Wind Speed (km/h)']]

lrm = linear_model.LinearRegression()

# fit method estimates the coefficients using OLS
lrm.fit(X, Y)

# Inspect the results.
print('\nCoefficients: \n', lrm.coef_)
print('\nIntercept: \n', lrm.intercept_)
# Out:
# Coefficients:
#  [-3.02918594 -0.11929075]
#
# Intercept:
#  2.4381054151877035

# %%
import statsmodels.api as sm
X=sm.add_constant(X)
results=sm.OLS(Y,X).fit()
display(results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                 1.949e+04
# Date:                Fri, 25 Jun 2021   Prob (F-statistic):               0.00
# Time:                        06:51:49   Log-Likelihood:            -1.7046e+05
# No. Observations:               96453   AIC:                         3.409e+05
# Df Residuals:                   96450   BIC:                         3.409e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# The estimated coefficients are statistically significant because of the values of P are zero. The signs of the estimated coefficients are same as previous expectation(LRM). Target and explanatory values are negative relation between each other.

# %% [markdown]
# - Next, include the interaction of *humidity* and *windspeed* to the model above and estimate the model using OLS. Are the coefficients statistically significant? Did the signs of the estimated coefficients for *humidity* and *windspeed* change? Interpret the estimated coefficients.

# %% [markdown]
# ##  3. House prices model
#
# In this exercise, you'll interpret your house prices model. To complete this assignment, submit a link in the gist file to the Jupyter notebook containing your solutions to the following tasks:

# %%
house_prices_df = pd.read_csv("https://djl-lms-assets.s3.eu-central-1.amazonaws.com/datasets/house_prices.csv", sep = ";")
house_prices_df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# - Run your house prices model again and interpret the results. Which features are statistically significant and which are not?

# %%
Xh = house_prices_df[["Id",	"MSSubClass"	,"LotFrontage",	"LotArea",	"OverallQual",	"OverallCond",	"YearBuilt",	"YearRemodAdd",	"MasVnrArea",	"BsmtFinSF1",	"BsmtFinSF2",	"BsmtUnfSF",	"TotalBsmtSF",	"1stFlrSF",	"2ndFlrSF",	"LowQualFinSF",	"GrLivArea",	"BsmtFullBath",	"BsmtHalfBath",	"FullBath",	"HalfBath",	"BedroomAbvGr",	"KitchenAbvGr",	"TotRmsAbvGrd",	"Fireplaces",	"GarageYrBlt",	"GarageCars",	"GarageArea",	"WoodDeckSF",	"OpenPorchSF",	"EnclosedPorch",	"3SsnPorch"	,"ScreenPorch",	"PoolArea",	"MiscVal",	"MoSold",	"YrSold"]]

# %%
import statsmodels.api as sm
Yh = house_prices_df['SalePrice']
Xh = house_prices_df[["Id",	"MSSubClass", 	"OverallQual",	"OverallCond",	"YearBuilt", "YearRemodAdd", "BsmtFinSF1","BsmtFinSF2", "BsmtUnfSF",	"TotalBsmtSF",	"1stFlrSF",	"2ndFlrSF",	"LowQualFinSF",	"GrLivArea",	"BsmtFullBath",	"BsmtHalfBath",	"FullBath",	"HalfBath",	"BedroomAbvGr","KitchenAbvGr", 	"TotRmsAbvGrd", "Fireplaces", "GarageCars", "GarageArea",	"WoodDeckSF", "OpenPorchSF",	"EnclosedPorch", "3SsnPorch"	,"ScreenPorch",	"PoolArea", "MiscVal",	"MoSold",	"YrSold"]]
Xh = sm.add_constant(Xh)
results=sm.OLS(Yh,Xh).fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     192.6
# Date:                Fri, 25 Jun 2021   Prob (F-statistic):               0.00
# Time:                        06:51:50   Log-Likelihood:                -17343.
# No. Observations:                1460   AIC:                         3.475e+04
# Df Residuals:                    1428   BIC:                         3.492e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
lrm = linear_model.LinearRegression()

# fit method estimates the coefficients using OLS
lrm.fit(Xh, Yh)

# Inspect the results.
print('\nCoefficients: \n', lrm.coef_)
print('\nIntercept: \n', lrm.intercept_)
# Out:
# Coefficients:
#  [-6.14118846e-10 -1.88780300e+00 -1.70814416e+02  1.74605347e+04
#   4.42569440e+03  3.33918335e+02  1.31096248e+02  1.18479737e+01
#  -1.58693127e+00  4.65559824e-01  1.07266022e+01  2.02516762e+01
#   1.97264558e+01 -7.51005092e+00  3.24680810e+01  9.20901136e+03
#   3.08789995e+03  3.98876173e+03 -1.50668668e+03 -1.03763807e+04
#  -1.34866551e+04  5.04493506e+03  4.47281713e+03  1.08509974e+04
#   2.14077411e+00  2.83731569e+01 -5.54066093e+00  6.04371188e+00
#   1.87172353e+01  5.61048348e+01 -4.09453097e+01 -5.73496532e-01
#  -1.27997225e+02 -7.96832765e+02]
#
# Intercept:
#  621726.3607299175

# %% [markdown]
# **Meaingful features are:**
#
# MSSubClass
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# BsmtFinSF1
# GrLivArea
# BsmtFullBath
# BedroomAbvGr
# KitchenAbvGr
# TotRmsAbvGrd
# Fireplaces
# GarageCars
# WoodDeckSF
# ScreenPorch
# PoolArea

# %% [markdown]
# **Not Meaningful features**
#
# Id
# OverallCond
# BsmtFinSF2
# BsmtUnfSF
# LowQualFinSF
# BsmtHalfBath
# FullBath
# HalfBath
# GarageArea
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# MiscVal
# MoSold
# YrSold

# %% [markdown]
# - Now, exclude the insignificant features from your model. Did anything change?

# %%
Y2 = house_prices_df['SalePrice']
X2 = house_prices_df[["MSSubClass", "OverallQual","OverallCond","YearBuilt","YearRemodAdd","BsmtFinSF1", "GrLivArea","BsmtFullBath", "BedroomAbvGr","KitchenAbvGr","TotRmsAbvGrd","Fireplaces","GarageCars","WoodDeckSF", "ScreenPorch","PoolArea"]]
X2 = sm.add_constant(X2)
results=sm.OLS(Y2,X2).fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.802
# Method:                 Least Squares   F-statistic:                     369.6
# Date:                Fri, 25 Jun 2021   Prob (F-statistic):               0.00
# Time:                        07:01:00   Log-Likelihood:                -17355.
# No. Observations:                1460   AIC:                         3.474e+04
# Df Residuals:                    1443   BIC:                         3.483e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
lrm.fit(X2, Y2)

# Inspect the results.
print('\nCoefficients: \n', lrm.coef_)
print('\nIntercept: \n', lrm.intercept_)
# Out:
# Coefficients:
#  [ 0.00000000e+00 -2.05523803e+02  1.87869963e+04  3.90041541e+03
#   3.57141252e+02  1.47572090e+02  1.62035810e+01  5.52572096e+01
#   7.85908755e+03 -1.01940514e+04 -8.80572685e+03  4.56946390e+03
#   4.75034922e+03  1.19517030e+04  2.94807266e+01  5.43442067e+01
#  -3.89812421e+01]
#
# Intercept:
#  -1053790.4182608575

# %% [markdown]
# R squared value is decreased. F-static value also decreased. AIC and BIC  are small decreased. Second prediction is little worse prediction. There are might be multicollinearity.

# %% [markdown]
# - Interpret the statistically significant coefficients by quantifying their relations with the house prices. Which features have more prominent effect on the house prices?

# %% [markdown]
# MSSubClass,PoolArea,KitchenAbvGr,BedroomAbvGr: **reversed** related to House Prices.
#
# OverallQual,OverallCond,BsmtFullBath,KitchenAbvGr,BsmtFullBath,TotRmsAbvGrd,Fireplaces, and GarageCars are so **big related** with Price.

# %% [markdown]
# - Do the results sound reasonable to you? If not, try to explain the potential reasons.

# %% [markdown]
# Thes sound is not meaningful. May be there is multicollinearty many features each others.

# %%
Y2 = house_prices_df['SalePrice']
X2 = house_prices_df[["MSSubClass", "OverallQual","OverallCond","YearBuilt","YearRemodAdd","BsmtFinSF1", "GrLivArea","BsmtFullBath", "BedroomAbvGr","KitchenAbvGr","TotRmsAbvGrd","Fireplaces","GarageCars","WoodDeckSF", "ScreenPorch"]]
X2 = sm.add_constant(X2)
results=sm.OLS(Y2,X2).fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     393.6
# Date:                Fri, 25 Jun 2021   Prob (F-statistic):               0.00
# Time:                        07:29:09   Log-Likelihood:                -17356.
# No. Observations:                1460   AIC:                         3.474e+04
# Df Residuals:                    1444   BIC:                         3.483e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
X2.corr()
# Out:
#               const  MSSubClass  ...  WoodDeckSF  ScreenPorch
# const           NaN         NaN  ...         NaN          NaN
# MSSubClass      NaN    1.000000  ...   -0.012579    -0.026030
# OverallQual     NaN    0.032628  ...    0.238923     0.064886
# OverallCond     NaN   -0.059316  ...   -0.003334     0.054811
# YearBuilt       NaN    0.027850  ...    0.224880    -0.050364
# YearRemodAdd    NaN    0.040581  ...    0.205726    -0.038740
# BsmtFinSF1      NaN   -0.069836  ...    0.204306     0.062021
# GrLivArea       NaN    0.074853  ...    0.247433     0.101510
# BsmtFullBath    NaN    0.003491  ...    0.175315     0.023148
# BedroomAbvGr    NaN   -0.023438  ...    0.046854     0.044300
# KitchenAbvGr    NaN    0.281721  ...   -0.090130    -0.051613
# TotRmsAbvGrd    NaN    0.040380  ...    0.165984     0.059383
# Fireplaces      NaN   -0.045569  ...    0.200019     0.184530
# GarageCars      NaN   -0.040110  ...    0.226342     0.050494
# ...

# %%
house_prices_df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage  ...    MoSold    YrSold  SalePrice
# Id             1.000000    0.011156    -0.010601  ...  0.021172  0.000712  -0.021917
# MSSubClass     0.011156    1.000000    -0.386347  ... -0.013585 -0.021407  -0.084284
# LotFrontage   -0.010601   -0.386347     1.000000  ...  0.011200  0.007450   0.351799
# LotArea       -0.033226   -0.139781     0.426095  ...  0.001205 -0.014261   0.263843
# OverallQual   -0.028365    0.032628     0.251646  ...  0.070815 -0.027347   0.790982
# OverallCond    0.012609   -0.059316    -0.059213  ... -0.003511  0.043950  -0.077856
# YearBuilt     -0.012713    0.027850     0.123349  ...  0.012398 -0.013618   0.522897
# YearRemodAdd  -0.021998    0.040581     0.088866  ...  0.021490  0.035743   0.507101
# MasVnrArea    -0.050298    0.022936     0.193458  ... -0.005965 -0.008201   0.477493
# BsmtFinSF1    -0.005024   -0.069836     0.233633  ... -0.015727  0.014359   0.386420
# ...

# %% [markdown]
# OverallQual and GarageCars&GrLivArea are so related each other. We can drop  GarageCars&GrLivArea features.
# There is no many features like this. We can not drop all of it.
